# %%
#import all the library
import pandas as pd
import glob
from scipy.stats import f_oneway
from scipy import stats

# %%
path = r'C:\Users\user\Desktop\file for p\F4.csv' # use path
df = pd.read_csv(path)# read the csv file
df
# Out:
#        sub ID ch_name  alpha_ph0  alpha_ph1  alpha_ph2  alpha_ph3  alpha_ph4  \
# 0    30620191      F4   0.020960   0.025986   0.017689   0.020539   0.017104
# 1    30620192      F4   0.020767   0.019835   0.019820   0.023130   0.012826
# 2    30620193      F4   0.011711   0.020265   0.031116   0.015259   0.016948
# 3     4062019      F4   0.021097   0.027566   0.017823   0.027882   0.032836
# 4    50620191      F4   0.017997   0.017691   0.020896   0.026919   0.023146
# 5    50620192      F4   0.016557   0.019819   0.014115   0.020486   0.012573
# 6    50620193      F4   0.010570   0.015082   0.021123   0.026976   0.021647
# 7     6062019      F4   0.014009   0.015858   0.013651   0.012467   0.010020
# 8     7062019      F4   0.026869   0.027417   0.020881   0.021252   0.021511
# 9   230520192      F4   0.042324   0.046109   0.013849   0.018827   0.018758
# 10  270520191      F4   0.003846   0.003393   0.004589   0.005143   0.004058
# ...

# %%
df[['tke_alpha_ph0','tke_alpha_ph1']].describe() #checking the mean and std of the data
# Out:
#        tke_alpha_ph0  tke_alpha_ph1
# count   1.400000e+01   1.400000e+01
# mean    5.386071e-07  -2.622143e-07
# std     1.003905e-06   7.866660e-07
# min    -1.510000e-06  -1.420000e-06
# 25%     5.230000e-08  -9.877500e-07
# 50%     4.110000e-07  -3.535000e-07
# 75%     1.332500e-06   4.955000e-07
# max     1.930000e-06   8.040000e-07

# %%
#computed the p value
ttest,pval = stats.ttest_rel(df['tke_alpha_ph0'], df['tke_alpha_ph1'])
print('p-tkeo',pval,'Stat-tkeo',ttest)
#print('Stat',ttest)
ttest,pval = stats.ttest_rel(df['alpha_ph0'], df['alpha_ph1'])
print('p-alpha',pval,'Stat-alpha',ttest)
# Out:
# p-tkeo 0.03770966394793812 Stat-tkeo 2.3133891895352194
# p-alpha 0.013532356109878763 Stat-alpha -2.854780996744727

# %%
#computed the p value
ttest,pval = stats.ttest_rel(df['tke_alpha_ph2'], df['tke_alpha_ph3'])
print('p-tkeo',pval,'Stat-tkeo',ttest)
#print('Stat',ttest)
ttest,pval = stats.ttest_rel(df['alpha_ph2'], df['alpha_ph3'])
print('p-alpha',pval,'Stat-alpha',ttest)
# Out:
# p-tkeo 0.18829037244716693 Stat-tkeo 1.388591380252138
# p-alpha 0.19818931464120212 Stat-alpha -1.3559896417834012

# %%
#computed the p value
ttest,pval = stats.ttest_rel(df['tke_alpha_ph4'], df['tke_alpha_ph5'])
print('p-tkeo',pval,'Stat-tkeo',ttest)
#print('Stat',ttest)
ttest,pval = stats.ttest_rel(df['alpha_ph4'], df['alpha_ph5'])
print('p-alpha',pval,'Stat-alpha',ttest)
# Out:
# p-tkeo 0.8470720564807199 Stat-tkeo 0.19674179482182957
# p-alpha 0.9877644735252586 Stat-alpha -0.01563310654101693

# %%
#computed the p value
ttest,pval = stats.ttest_rel(df['tke_alpha_ph6'], df['tke_alpha_ph7'])
print('p-tkeo',pval,'Stat-tkeo',ttest)
#print('Stat',ttest)
ttest,pval = stats.ttest_rel(df['alpha_ph6'], df['alpha_ph7'])
print('p-alpha',pval,'Stat-alpha',ttest)
# Out:
# p-tkeo 0.47190577102347075 Stat-tkeo -0.7409339830286319
# p-alpha 0.24709516568104828 Stat-alpha -1.2119620090246408
