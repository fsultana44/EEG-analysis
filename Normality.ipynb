# %%
from numpy.random import seed
from numpy.random import randn
from matplotlib import pyplot
import pandas as pd
import glob
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from statsmodels.graphics.gofplots import qqplot
from matplotlib import pyplot

# %%
path1 = r'C:\Users\user\Desktop\Boxplot\Combine_without24\F4.csv'
df1 = pd.read_csv(path1)
df1
# Out:
#        Sub ID  thet_dif1  thet_dif2  thet_dif3  thet_dif4  thet_nor 1  \
# 0    30620191  -0.009540   0.001991   0.018964   0.028116    0.821670
# 1    30620192   0.003748  -0.002054  -0.023315   0.009593    1.089755
# 2    30620193  -0.004674  -0.017019  -0.007854   0.024751    0.848002
# 3    40620191   0.005635  -0.022999   0.002769   0.018493    1.122469
# 4    50620191  -0.003798   0.005110  -0.001605   0.010900    0.885900
# 5    50620192   0.008938  -0.007281  -0.005852  -0.002301    1.324482
# 6    50620193   0.015555   0.020676  -0.005728   0.011076    1.400344
# 7    60620191   0.017451  -0.012030  -0.001922   0.018590    2.038033
# 8    70620191  -0.009844  -0.006000  -0.016490   0.011627    0.812868
# 9   230520192   0.001394   0.001954  -0.019244   0.025229    1.158211
# 10  270520191  -0.003476   0.000615  -0.001185  -0.006105    0.585946
# 11  270520192  -0.001313  -0.007705   0.000891  -0.007584    0.930575
# ...

# %%
df= df1.iloc[:,9]
df2 =df1.iloc[:,10]
df3 =df1.iloc[:,11]
df4 =df1.iloc[:,12]
frame = pd.concat([df,df2,df3,df4],axis=0,ignore_index=True,sort=True)
frame
# Out:
# 0     0.005026
# 1    -0.000932
# 2     0.008555
# 3     0.006469
# 4    -0.000306
# 5     0.003261
# 6     0.004512
# 7     0.001849
# 8     0.000548
# 9     0.003785
# 10   -0.000452
# 11    0.002543
# 12   -0.002937
# 13    0.001585
# 14    0.002849
# 15    0.003310
# 16   -0.015856
# 17    0.010058
# 18    0.006023
# 19    0.006372
# 20    0.005853
# 21   -0.001184
# 22    0.000372
# 23    0.004978
# 24    0.000554
# 25    0.004676
# 26   -0.000726
# 27    0.003431
# 28    0.004334
# 29   -0.006596
# 30    0.001842
# 31   -0.013823
# 32    0.000199
# 33    0.006059
# 34   -0.001446
# 35    0.000842
# 36    0.003759
# 37   -0.004909
# 38    0.001335
# 39    0.007376
# 40    0.002986
# 41   -0.001631
# 42    0.005533
# 43    0.008416
# 44    0.012657
# 45   -0.002236
# 46    0.002353
# 47   -0.010110
# 48   -0.001229
# 49    0.009822
# 50   -0.005463
# 51    0.003454
# 52    0.001243
# 53    0.003315
# 54    0.003780
# 55   -0.003495
# dtype: float64

# %%
qqplot(frame, line='s')
pyplot.show()

# %%
pf= df1.iloc[:,26]
pf2 =df1.iloc[:,27]
pf3 =df1.iloc[:,28]
pf4 =df1.iloc[:,29]
frame1 = pd.concat([pf,pf2,pf3,pf4],axis=0,ignore_index=True,sort=True)
frame1
# Out:
# 0     3.300000e-07
# 1    -1.780000e-06
# 2    -6.630000e-07
# 3    -2.590000e-07
# 4    -3.010000e-06
# 5    -3.000000e-06
# 6    -8.300000e-08
# 7    -1.080000e-06
# 8     7.990000e-07
# 9    -9.630000e-07
# 10    6.460000e-07
# 11   -5.510000e-07
# 12    6.570000e-07
# 13   -2.240000e-06
# 14   -1.860000e-06
# 15    3.210000e-07
# 16   -1.750000e-06
# 17   -2.880000e-06
# 18    9.420000e-07
# 19   -5.190000e-06
# 20    1.770000e-06
# 21    2.690000e-07
# 22   -8.430000e-07
# 23   -2.640000e-07
# 24    8.270000e-07
# 25   -3.100000e-07
# 26    3.460000e-07
# 27   -7.100000e-07
# 28    3.150000e-07
# 29    1.920000e-07
# 30   -6.450000e-07
# 31    4.890000e-07
# 32    2.140000e-06
# 33   -1.340000e-06
# 34    5.360000e-07
# 35    1.400000e-08
# 36   -1.910000e-06
# 37    1.520000e-07
# 38    2.700000e-07
# 39   -6.720000e-07
# 40    3.500000e-07
# 41    1.340000e-06
# 42   -5.150000e-07
# 43    4.230000e-06
# 44   -2.630000e-07
# 45    3.400000e-07
# 46    1.700000e-06
# ...

# %%
pf4
# Out:
# 0    -5.150000e-07
# 1     4.230000e-06
# 2    -2.630000e-07
# 3     3.400000e-07
# 4     1.700000e-06
# 5     2.480000e-06
# 6    -7.690000e-07
# 7    -1.750000e-06
# 8     8.480000e-07
# 9     2.900000e-07
# 10    2.820000e-06
# 11   -1.840000e-06
# 12   -1.440000e-06
# 13   -9.900000e-07
# Name: T-alp dif4, dtype: float64

# %%
qqplot(frame1, line='s')
pyplot.show()
